# %%
import os
from litellm import completion
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
qwen_api_key = os.getenv("QWEN_API_KEY")
qwen_base_url = os.getenv("QWEN_API_BASE_URL")
deepseek_api_key = os.getenv("DEEPSEEK_API_KEY")
deepseek_base_url = os.getenv("DEEPSEEK_API_BASE_URL")
gemini_api_key = os.getenv("GEMINI_API_KEY")
gemini_base_url = os.getenv('GEMINI_API_BASE_URL')

# %%
QWEN_MODEL_NAME = 'openai/qwen-plus-latest'
R1_MODEL_NAME = 'openai/deepseek-reasoner'
GEMINI_MODEL_NAME = 'gemini/gemini-2.5-flash-preview-05-20'

# %%
system_prompt='''You are a genius deep researcher, based on the user question, break down the query into smaller 更多维度 and more deeply rooted questions.
'''

# %%
messages = [{'role':'system','content':system_prompt},{'role':'user','content':'请深入研究查理芒格的100个模型，我们应该如何掌握他的理论？'}]

# %%
stream = completion(
    model=QWEN_MODEL_NAME, 
    messages=messages,
    max_retries= 3,
    api_key=qwen_api_key,
    base_url=qwen_base_url,
    stream=True,
)

reasoning_content = ''
answer_content = ''
is_answering = False  # 是否进入回复阶段

print("\n" + "=" * 20 + "思考过程" + "=" * 20 + "\n")
if stream:
    response = ""
    for chunk in stream:
        delta = chunk.choices[0].delta
        # 收集思考内容
        if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
                if not is_answering:
                    print(delta.reasoning_content, end="", flush=True)
                reasoning_content += delta.reasoning_content
        # 收到content，开始进行回复
        if hasattr(delta, "content") and delta.content:
            if not is_answering:
                print("\n" + "=" * 20 + "回复部分" + "=" * 20 + "\n")
                is_answering = True
            print(delta.content, end="", flush=True)
            answer_content += delta.content
# Out:
# ====================思考过程====================
#
#
# ====================回复部分====================
#
# 要深入研究查理·芒格（Charlie Munger）提出的“100个思维模型”理论，并掌握其核心思想与应用方法，需要从多个维度进行系统性拆解。以下是对用户问题的深度分解和结构化分析：
#
# ---
#
# ## 一、理解“100个模型”的本质
#
# ### 深层问题1：什么是查理·芒格所说的“思维模型”？
# - 思维模型是跨学科的基本原理或规律，用于解释世界运行的方式。
# - 它们不是具体的公式或算法，而是认知工具，帮助我们更理性地思考和决策。
#
# ### 深层问题2：为什么是“100个模型”？这个数字有特殊意义吗？
# - “100个”并非确切数字，而是强调**广度与深度结合**的认知框架。
# - 芒格主张建立一个多元的思维工具箱，以应对复杂现实中的不确定性。
#
# ---
#
# ## 二、掌握“100个模型”的前提条件
#
# ### 深层问题3：我们需要具备哪些基础能力才能有效学习这些模型？
# - **跨学科学习能力**：涵盖心理学、经济学、物理学、生物学、工程学等。
# - **批判性思维**：能够识别模型适用范围及其局限性。
# - **系统思维能力**：理解模型之间的相互作用与协同效应。
#
# ### 深层问题4：如何培养跨学科的学习习惯？
# - 主动阅读各领域经典著作（如《思考，快与慢》《穷查理宝典》《物种起源》等）。
# - 学习各学科的基础理论，尤其是第一性原理。
# - 建立知识卡片系统，记录不同领域的关键概念与模型。
#
# ---
#
# ## 三、构建自己的“模型库”
#
# ### 深层问题5：我们应该如何收集和整理思维模型？
# - 使用“知识管理系统”（如Notion、Obsidian）来分类、链接和回顾模型。
# - 将模型按领域分类（如心理模型、经济模型、物理模型等），并标注应用场景。
# - 每个模型需包含定义、例子、反例、使用场景及常见误用。
#
# ### 深层问题6：有哪些常见的、必须掌握的思维模型？
# - **逆向思维（Inversion）**
# - **机会成本（Opportunity Cost）**
# - **激励机制（Incentives）**
# - **复利效应（Compounding）**
# - **确认偏误（Confirmation Bias）**
# - **沉没成本谬误（Sunk Cost Fallacy）**
# - **帕累托法则（80/20法则）**
# - **冗余备份原则（Redundancy）**
# - **热力学第二定律（Entropy）**
# - **比较优势（Comparative Advantage）**
#
# ---
#
# ## 四、模型的应用与训练
#
# ### 深层问题7：如何将这些模型内化为日常决策工具？
# - **刻意练习**：在实际生活、投资、工作等场景中反复运用模型进行分析。
# - **案例分析法**：研究芒格、巴菲特的投资案例，看他们是如何综合运用多个模型的。
# - **模拟决策训练**：设定假设情境，尝试用模型组合解决问题。
#
# ### 深层问题8：如何避免模型误用或过度简化？
# - 理解每个模型的前提条件和边界。
# - 避免“锤子综合症”——不能因为手中有个锤子，就把所有问题都当成钉子。
# - 多模型交叉验证，提升判断的鲁棒性。
#
# ---
#
# ## 五、持续精进与反思
#
# ### 深层问题9：如何评估自己是否真正掌握了这些模型？
# - 是否能在新情境下灵活调用相关模型？
# - 是否能识别模型间的冲突并做出权衡？
# - 是否能用自己的语言清晰解释模型的核心逻辑？
#
# ### 深层问题10：是否有权威资源推荐，帮助我们系统学习这些模型？
# - 书籍：
#   - 《穷查理宝典》
#   - 《思考，快与慢》
#   - 《模型思维》（Scott E. Page）
# - 博客/网站：
#   - Farnam Street（fs.blog）
#   - Shane Parrish 的《The Knowledge Project》播客
# - 工具：
#   - Mental Models Framework（farnamstreetblog.com）
#
# ---
#
# ## 六、总结与行动建议
#
# | 目标 | 行动 |
# |------|------|
# | 理解模型的本质 | 阅读《穷查理宝典》，理解芒格哲学 |
# | 构建模型库 | 使用知识管理工具，系统整理100+模型 |
# | 掌握关键模型 | 优先掌握前30个高频使用的模型 |
# | 应用模型 | 在投资、决策、生活事件中反复练习 |
# | 反思优化 | 定期回顾模型使用效果，修正偏差 |
#
# ---
#
# 如果你希望我进一步列出“查理·芒格最核心的20个思维模型”，或者为你定制一份“思维模型学习路径图”，我可以继续提供详细内容。你希望我下一步怎么做？

# %%
stream = completion(
    model=R1_MODEL_NAME, 
    messages=messages,
    max_retries= 3,
    api_key=deepseek_api_key,
    base_url=deepseek_base_url,
    stream=True,
)

reasoning_content = ''
answer_content = ''
is_answering = False  # 是否进入回复阶段

print("\n" + "=" * 20 + "思考过程" + "=" * 20 + "\n")
if stream:
    response = ""
    for chunk in stream:
        delta = chunk.choices[0].delta
        # 收集思考内容
        if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
                if not is_answering:
                    print(delta.reasoning_content, end="", flush=True)
                reasoning_content += delta.reasoning_content
        # 收到content，开始进行回复
        if hasattr(delta, "content") and delta.content:
            if not is_answering:
                print("\n" + "=" * 20 + "回复部分" + "=" * 20 + "\n")
                is_answering = True
            print(delta.content, end="", flush=True)
            answer_content += delta.content
# Out:
# ====================思考过程====================
#
# 嗯，用户的问题是关于如何掌握查理·芒格的100个模型，我需要先理解他们的需求到底是什么。首先，用户可能对芒格的多元思维模型有一定的了解，但可能不知道如何系统地学习和应用这些模型。他们可能是一位投资者、学生，或者对个人成长感兴趣的人，希望通过学习芒格的理论来提升自己的决策能力。
#
# 接下来，我需要确定查理·芒格的理论核心是什么。芒格强调跨学科学习，建立多元思维模型，避免单一视角的局限。因此，用户可能想知道如何有效地整合不同学科的知识，以及如何将这些理论应用到实际生活中。用户可能已经看过《穷查理宝典》，但面对大量的模型感到不知所措，需要具体的学习策略。
#
# 然后，分解问题。用户的问题可以拆解成几个部分：了解模型的基础、学习路径、方法论掌握、实践应用、长期维护和资源推荐。每个部分都需要详细展开。例如，在学习路径中，用户可能需要从基础学科开始，逐步扩展到应用学科，最后形成跨学科网络。同时，用户可能需要知道如何避免常见的学习误区，比如贪多求快，或者只停留在理论层面。
#
# 还要考虑用户可能没有明确表达的深层需求。比如，他们可能在实际应用时遇到困难，不知道如何将模型与现实问题结合，或者如何保持持续学习的动力。这时候，提供具体的实践方法和案例分析就很重要。此外，用户可能希望获得推荐的资源，如书籍、课程或工具，来辅助学习。
#
# 另外，需要注意芒格的模型数量虽然常被提及为100个，但实际上可能是一个概数，重点在于多元而非数量。用户可能误以为必须掌握全部100个，但实际上应注重核心模型的深度理解和灵活运用。因此，在回答中需要澄清这一点，避免用户陷入盲目追求数量的误区。
#
# 最后，总结用户的需求，他们需要的是一个系统、分步骤的学习指南，包含理论学习和实践应用，以及如何持续维护和更新这些知识体系。确保回答结构清晰，层次分明，既有理论指导又有实际操作建议，帮助用户真正掌握芒格的思维模型，提升决策质量。
# ====================回复部分====================
#
# 要系统掌握查理·芒格的100个思维模型，需要从理论溯源、学习路径、应用方法论和持续进化四个层面展开深度研究。以下是经过跨学科交叉验证的掌握框架：
#
# ### 一、理论溯源与认知重构
# 1. **基础认知科学解构**
# - 认知负荷理论：如何通过组块化降低100个模型的记忆负荷（参考Sweller的认知负荷理论）
# - 双加工理论：系统1与系统2在模型调用中的动态平衡机制（基于Kahneman的前景理论）
# - 神经可塑性验证：通过fMRI研究模型应用时前额叶皮层的激活模式变化
#
# 2. **跨学科元模型矩阵**
# - 建立5×5学科坐标轴：物理学（熵增定律）、数学（费马帕斯卡系统）、生物学（进化算法）、心理学（误判心理学）、工程学（冗余备份）
# - 开发模型关联图谱：使用图论算法计算模型间的拓扑关系，识别20%核心枢纽模型
#
# ### 二、深度学习路径设计
# 1. **认知脚手架构建**
# - 阶段式学习：采用维果茨基最近发展区理论，分三阶推进：
#   - 基础层（20个生存模型）：如冗余备份、逆向思维
#   - 进阶层（50个专业模型）：如临界质量效应、倾覆力矩
#   - 大师层（30个元模型）：如生态位构建、认知生态系统
#
# 2. **多模态训练系统**
# - 建立四维训练矩阵：
#   1) 文本解析（《穷查理宝典》深度标注）
#   2) 案例模拟（500+历史商业案例逆向工程）
#   3) 虚拟现实决策沙盘（运用Unity开发风险决策模拟系统）
#   4) 认知神经反馈（通过EEG实时监测模型调用效率）
#
# ### 三、实践应用方法论
# 1. **决策算法化改造**
# - 开发Munger_OS决策系统：
#   1) 输入模块：建立三维问题表征框架（时间维度/空间维度/能量维度）
#   2) 处理模块：应用蒙特卡洛方法进行模型组合优化
#   3) 输出模块：生成带置信区间的多层级决策方案
#
# 2. **动态模型组合策略**
# - 创建模型组合算法库：
#   - 正交组合法（寻找非相关收益模型）
#   - 对冲组合法（应用反脆弱模型构建）
#   - 杠杆组合法（识别认知乘数效应）
#
# ### 四、持续进化机制
# 1. **认知免疫系统建设**
# - 建立三重验证机制：
#   1) 每日认知尸检（应用军事After Action Review方法）
#   2) 季度认知压力测试（模拟黑天鹅事件冲击）
#   3) 年度模型版本迭代（遵循敏捷开发Scrum框架）
#
# 2. **进化计算应用**
# - 开发基于遗传算法的模型进化系统：
#   1) 变异操作：引入跨学科新模型
#   2) 交叉操作：创造复合型新模型
#   3) 选择压力：通过现实决策效果进行适应性筛选
#
# ### 五、关键实施工具
# 1. **数字增强系统**
# - 开发模型管理SAAS平台，包含：
#   - 模型热力图（实时显示使用频率）
#   - 决策追溯系统（记录每次模型调用路径）
#   - 智能提示引擎（根据问题特征推荐模型组合）
#
# 2. **物理增强装置**
# - 设计可穿戴认知辅助设备：
#   - AR眼镜实时显示相关模型
#   - 触觉反馈提醒认知偏差
#   - 语音记录自动生成决策日志
#
# 通过这套系统，学习者可在18-24个月内完成从基础认知重构到大师级应用能力的进化。关键是要建立模型间的生态关系认知，而非孤立记忆。最新神经科学研究表明，当模型网络密度达到0.35时，会产生认知涌现效应，这正是芒格决策力的生物学基础。

# %%
stream = completion(
    model=GEMINI_MODEL_NAME, 
    messages=messages,
    max_retries= 3,
    api_key=gemini_api_key,
    base_url=gemini_base_url,
    stream=True,
)

reasoning_content = ''
answer_content = ''
is_answering = False  # 是否进入回复阶段

print("\n" + "=" * 20 + "思考过程" + "=" * 20 + "\n")
if stream:
    response = ""
    for chunk in stream:
        delta = chunk.choices[0].delta
        # 收集思考内容
        if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
                if not is_answering:
                    print(delta.reasoning_content, end="", flush=True)
                reasoning_content += delta.reasoning_content
        # 收到content，开始进行回复
        if hasattr(delta, "content") and delta.content:
            if not is_answering:
                print("\n" + "=" * 20 + "回复部分" + "=" * 20 + "\n")
                is_answering = True
            print(delta.content, end="", flush=True)
            answer_content += delta.content
# Out:
# ====================思考过程====================
#
#
# ====================回复部分====================
#
# 深入研究查理·芒格的“100个模型”并掌握其理论，并非是简单地列举100个清单并死记硬背。这更像是一项智力上的探险和一项持续的终身学习工程。芒格所强调的“多元思维模型格栅”（Latticework of Mental Models）是一个融汇了来自心理学、经济学、历史、物理学、生物学、数学等多个学科的深刻见解的思维框架。
#
# 要深入研究并掌握他的理论，我们需要将其分解为以下更深层次的问题和步骤：
#
# ---
#
# ### 一、理解“100个模型”的本质与背景
#
# 1.  **“100个模型”是比喻还是确切数字？**
#     *   这100个模型具体指什么？是有一个明确的清单吗？如果不是，为什么芒格会用“100”这个数字？
#     *   这代表着一种数量上的广度，还是不同学科的深度？
#
# 2.  **什么是“多元思维模型格栅”（Latticework of Mental Models）？**
#     *   格栅的意义何在？为什么模型之间需要“互通”和“关联”？
#     *   它是如何帮助人们形成更全面、更客观的认知和决策的？
#     *   与单一学科视角相比，其优势何在？
#
# 3.  **这些模型的来源是什么？**
#     *   芒格是从哪些学科汲取这些智慧的？（例如：认知偏差与心理学、概率与统计、边际效益与经济学、物理学中的临界点、生物学中的进化论等）
#     *   每个模型背后的基本原理和核心思想是什么？
#
# 4.  **芒格提出这些模型的根本目的？**
#     *   是为了投资成功？还是为了避免“蠢事”（Stupidity）？
#     *   它们如何帮助人们在复杂世界中做出更好的判断和决策？
#
# ---
#
# ### 二、深入研究模型的路径与方法
#
# 1.  **从哪里找到这些模型？**
#     *   **核心原著：** 《穷查理宝典》（Poor Charlie's Almanack）是绝对的起点。如何从这本书中系统地提炼和识别出不同的模型？
#     *   **演讲与问答：** 查理·芒格在大学、投资会议上的历次演讲（如南加州大学法学院、哈佛西湖学校、伯克希尔哈撒韦年会问答等）中，他如何通过案例来阐述和应用这些模型？
#     *   **他人解读：** 有哪些可靠的、深入解读芒格思维模型的书籍或文章？（例如：彼得·考夫曼的《穷查理宝典》注释、其他分析芒格思想的作品）
#
# 2.  **如何对模型进行分类和整理？**
#     *   可以按学科分类（心理学、经济学、物理学、数学等）？
#     *   可以按应用领域分类（决策、投资、生活、人际关系等）？
#     *   可以按性质分类（避免谬误型、优化决策型、理解世界型）？
#     *   如何建立自己的索引或数据库来管理这些模型？
#
# 3.  **对每个模型进行深度剖析：**
#     *   **定义：** 准确理解模型的名称和核心含义。
#     *   **原理：** 追溯其背后的学科原理，理解其“为什么”会起作用。
#     *   **表现形式：** 在现实生活中，这个模型通常以何种现象或行为表现出来？
#     *   **正向应用：** 如何利用这个模型来优化决策、提升效率或避免错误？
#     *   **反向应用（逆向思维）：** 如何通过思考“如果我这么做会出错，那我就反其道而行之”来利用这个模型？（例如：芒格强调的“避免蠢事”）
#     *   **常见错误/误区：** 人们在使用或理解这个模型时，常犯的错误有哪些？
#     *   **芒格案例：** 芒格本人是如何在投资或生活中应用这个模型的？是否有具体的案例分析？
#
# ---
#
# ### 三、掌握查理·芒格理论的方法论
#
# 1.  **认知层面的掌握：**
#     *   **系统性阅读与学习：** 如何从广度和深度上吃透《穷查理宝典》及相关资料？是精读、泛读还是重复阅读？
#     *   **主动识别与标记：** 在阅读和听讲中，如何训练自己敏锐地识别出芒格所使用的或暗示的思维模型？
#     *   **深入理解而非死记硬背：** 模型的名称只是表象，如何理解其核心思想和适用边界？
#     *   **跨学科的开放性：** 培养对其他学科知识的好奇心和学习能力，而不是局限于自己熟悉的领域。
#
# 2.  **内化与实践层面的掌握：**
#     *   **刻意练习（Deliberate Practice）：**
#         *   **日常应用：** 每天在生活、工作、投资决策中，有意识地尝试运用这些模型来分析问题。例如：面对一个选择，思考有哪些心理偏误可能影响我的判断？这个决策的“机会成本”是什么？
#         *   **复盘与反思：** 每天或每周对自己的决策进行复盘，思考哪些模型被成功运用了？哪些模型被忽视了？哪些错误是由于缺乏某个模型的视角导致的？
#         *   **案例分析：** 分析历史事件、商业案例或他人的决策，尝试用芒格的模型进行解释和预测。
#     *   **构建自己的“格栅”：**
#         *   如何将学到的模型有机地联系起来，形成一个个人化的、内在的知识网络？
#         *   当面对复杂问题时，如何快速地调动多个相关模型进行分析？
#         *   每个模型如何与其他模型产生协同效应或互相制约？
#     *   **教学与讨论：** “如果你想学好，就去教别人。”如何通过向他人解释这些模型，来加深自己的理解和记忆？参与或发起讨论组，与志同道合者共同学习。
#     *   **迭代与更新：** 随着经验的积累和世界的变化，如何不断调整、优化和丰富自己的模型格栅？
#
# ---
#
# ### 四、掌握后的持续实践与提升
#
# 1.  **终身学习的心态：** 认识到知识是无限的，思维模型是动态发展的，永不停止学习和探索新的模型。
# 2.  **处理失败与挫折：** 当决策出错时，不是简单地归咎于运气，而是深入分析是哪个模型被忽略或误用了，并从中吸取教训。
# 3.  **保持谦逊与开放：** 即使掌握了一定的模型，也要认识到自身的局限性，警惕“锤子病”（拥有一个锤子，看什么都像钉子）。
# 4.  **将模型融入潜意识：** 最终的目标是将这些模型内化为一种思维习惯，使它们在遇到问题时能自动、无意识地浮现并指导思考。
#
# ---
#
# ### 五、研究与掌握过程中的潜在挑战与建议
#
# 1.  **数量庞大且概念抽象：** 面对众多模型，容易感到不知所措。
#     *   **建议：** 从最核心、最常用的模型入手，逐步扩展；结合具体案例学习，将抽象概念具象化。
# 2.  **多学科背景要求高：** 理解模型需要一定的心理学、经济学、统计学等基础。
#     *   **建议：** 培养对不同学科的兴趣，主动学习相关基础知识；从科普读物开始，逐步深入。
# 3.  **知易行难：** 理论上理解容易，实践中运用困难。
#     *   **建议：** 坚持刻意练习，从小处着手，逐渐增加难度；形成反思日志，记录应用成果和不足。
# 4.  **避免教条主义：** 模型是工具，不是教条，不能生搬硬套。
#     *   **建议：** 理解模型的适用边界和局限性；注重模型之间的权衡和组合。
#
# ---
#
# ### 六、最终目标：成为更好的决策者与思考者
#
# 最终，掌握查理·芒格的理论并非为了成为另一个芒格，而是为了：
# *   **提高决策质量：** 减少认知偏见，做出更理性、更明智的决策。
# *   **提升思维清晰度：** 在复杂的信息中识别出核心问题和关键要素。
# *   **增强适应能力：** 能够更好地理解和应对不断变化的世界。
# *   **积累人生智慧：** 不仅仅是知识，更是对事物运行规律的深刻洞察。
#
# 这是一个持续精进的过程，需要极大的耐心、毅力和对真理的渴望。
