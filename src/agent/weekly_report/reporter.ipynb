# %%
from agno.agent import Agent
from agno.tools import tool
from agno.models.openai import OpenAILike
import json
import httpx
from typing import Any,Callable,Dict

#------------------ settings ------------------
import os
from dotenv import load_dotenv
load_dotenv()
api_key=os.getenv("QWEN_API_KEY")
base_url=os.getenv("QWEN_API_BASE_URL")
local_base_url = 'http://192.168.0.166:8000/v1'
local_model_name = 'Qwen3-235B'
model_name = 'qwen-plus-latest'

local_settings = {
  'api_key' : '123',
  'base_url' : local_base_url,
  'id' : local_model_name
}

qwen_settings = {
  'api_key' : api_key,
  'base_url' : base_url,
  'id' : model_name
}

settings = qwen_settings
#------------------ settings ------------------

# %%
response_json = '''
{
    "errcode": 0,
    "errmsg": "获取数据成功",
    "data": {
        "view": null,
        "totalPages": 1,
        "sumLine": null,
        "sumMap": null,
        "totalElements": 7,
        "content": [
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-30 08:33:20",
                    "sequenceStatus": "COMPLETED",
                    "ms": "发布和天国际、智能、能环、重工、深圳分公司和上海分公司的名片小程序二维码。",
                    "name": "陆莹辉的重点项目记录2025-05-30 08:33:20",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-30 08:33:20",
                    "id": "b43af2d1e5274e818ccf823a2a7e9e50",
                    "gs": {
                        "name": "综合",
                        "displayCode": "name",
                        "id": "9d7f5def31f44319b9f00c438e099911",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-30 08:33:20",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-30 08:33:20",
                "id": "b43af2d1e5274e818ccf823a2a7e9e50",
                "ownerId": "bf2f6ac262f1487889e51e83a560ea03",
                "ownerDeptQueryCode": "",
                "name": "陆莹辉的重点项目记录2025-05-30 08:33:20",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-30 10:12:26",
                    "sequenceStatus": "COMPLETED",
                    "ms": "完成信息与数字化中心一部一屏需求研发穿透场景设计，初版已发布。",
                    "name": "陆莹辉的重点项目记录2025-05-30 08:30:05",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-30 08:30:05",
                    "id": "1c8ebfbcd86d49e689e3df2efb0f9801",
                    "gs": {
                        "name": "数字化企业大脑",
                        "displayCode": "name",
                        "id": "1e1262fc39394440884aef60551f1908",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-30 10:12:26",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-30 08:30:05",
                "id": "1c8ebfbcd86d49e689e3df2efb0f9801",
                "ownerId": "bf2f6ac262f1487889e51e83a560ea03",
                "ownerDeptQueryCode": "",
                "name": "陆莹辉的重点项目记录2025-05-30 08:30:05",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-29 11:41:39",
                    "sequenceStatus": "COMPLETED",
                    "ms": "设备安装调试完成，表单接口完成",
                    "name": "李思齐的重点项目记录2025-05-29 11:41:39",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-29 11:41:39",
                    "id": "aa9a88d23520452cad913542230f9255",
                    "gs": {
                        "name": "智能会议室改造",
                        "displayCode": "name",
                        "id": "367bf69468714704948f874278877f56",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-29 11:41:39",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-29 11:41:39",
                "id": "aa9a88d23520452cad913542230f9255",
                "ownerId": "9024574bbd4d4fcea03c375d19daee9f",
                "ownerDeptQueryCode": "",
                "name": "李思齐的重点项目记录2025-05-29 11:41:39",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-29 11:41:14",
                    "sequenceStatus": "COMPLETED",
                    "ms": "完成票据托收功能",
                    "name": "李思齐的重点项目记录2025-05-29 11:41:14",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-29 11:41:14",
                    "id": "152f7465174e4132bccd82091fe711b4",
                    "gs": {
                        "name": "财务部信息化需求",
                        "displayCode": "name",
                        "id": "794bfbad8e6f444c97b28267ac905a8b",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-29 11:41:14",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-29 11:41:14",
                "id": "152f7465174e4132bccd82091fe711b4",
                "ownerId": "9024574bbd4d4fcea03c375d19daee9f",
                "ownerDeptQueryCode": "",
                "name": "李思齐的重点项目记录2025-05-29 11:41:14",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-28 17:14:26",
                    "sequenceStatus": "COMPLETED",
                    "ms": "166Chat服务部署及上线",
                    "name": "李思齐的重点项目记录2025-05-28 17:14:26",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-28 17:14:26",
                    "id": "bdad0176fe7141008e0a5dd9f8c77dd8",
                    "gs": {
                        "name": "综合",
                        "displayCode": "name",
                        "id": "9d7f5def31f44319b9f00c438e099911",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-28 17:14:26",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-28 17:14:26",
                "id": "bdad0176fe7141008e0a5dd9f8c77dd8",
                "ownerId": "9024574bbd4d4fcea03c375d19daee9f",
                "ownerDeptQueryCode": "",
                "name": "李思齐的重点项目记录2025-05-28 17:14:26",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-30 08:32:31",
                    "sequenceStatus": "COMPLETED",
                    "ms": "发布市场开发部、研发中心、矿业公司、水工公司、越南办事处、总图运输分院的名片小程序二维码。",
                    "name": "陆莹辉的重点项目记录2025-05-27 15:07:20",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "bf2f6ac262f1487889e51e83a560ea03",
                            "type": 3,
                            "name": "陆莹辉",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPD1W_xF-lMPxgYA_96_96.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-27 15:07:20",
                    "id": "172cbd69a4784d77b8eb81683e88caf9",
                    "gs": {
                        "name": "综合",
                        "displayCode": "name",
                        "id": "9d7f5def31f44319b9f00c438e099911",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-30 08:32:31",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-27 15:07:20",
                "id": "172cbd69a4784d77b8eb81683e88caf9",
                "ownerId": "bf2f6ac262f1487889e51e83a560ea03",
                "ownerDeptQueryCode": "",
                "name": "陆莹辉的重点项目记录2025-05-27 15:07:20",
                "sheetCode": null,
                "participants": null
            },
            {
                "loadedFromDb": false,
                "schemaCode": "sccdxxgl",
                "status": null,
                "activityCodes": null,
                "data": {
                    "owner": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "modifiedTime": "2025-05-26 16:59:35",
                    "sequenceStatus": "COMPLETED",
                    "ms": "166 AI服务器配置以及测试",
                    "name": "李思齐的重点项目记录2025-05-26 16:59:35",
                    "creater": [
                        {
                            "excelType": null,
                            "id": "9024574bbd4d4fcea03c375d19daee9f",
                            "type": 3,
                            "name": "李思齐",
                            "imgUrl": "https://static-legacy.dingtalk.com/media/lALPDfmVSqFjr0jNAWHNAWE_353_353.png",
                            "departmentId": null,
                            "departments": null,
                            "parentId": null,
                            "fullDepartment": "中冶长天国际工程有限责任公司/职能部门/信息与数字化中心",
                            "sourceParticipantType": null,
                            "corpId": null,
                            "code": null,
                            "queryCode": null
                        }
                    ],
                    "createdTime": "2025-05-26 16:59:35",
                    "id": "e8d2e23fea7a4baba640107d9af79f28",
                    "gs": {
                        "name": "综合",
                        "displayCode": "name",
                        "id": "9d7f5def31f44319b9f00c438e099911",
                        "schemaCode": "project",
                        "propertyType": 0
                    },
                    "workflowInstanceId": null
                },
                "childPageInfo": null,
                "extendInfo": null,
                "sequenceStatus": "COMPLETED",
                "modifiedTime": "2025-05-26 16:59:35",
                "sequenceNo": "",
                "workflowInstanceId": "",
                "createdTime": "2025-05-26 16:59:35",
                "id": "e8d2e23fea7a4baba640107d9af79f28",
                "ownerId": "9024574bbd4d4fcea03c375d19daee9f",
                "ownerDeptQueryCode": "",
                "name": "李思齐的重点项目记录2025-05-26 16:59:35",
                "sheetCode": null,
                "participants": null
            }
        ]
    }
}
'''

# %%
agent = Agent(model=OpenAILike(**settings),description='你是一位报表生成专家.',instructions=['首先按照用户进行分组','根据用户的项目进行分组汇总项目事项','不要遗漏任何项目和项目事项信息','报告标题为:{上周一日期}-{上周日日期}周报'],add_datetime_to_instructions=True,markdown=True,telemetry=False)

# %%
response = agent.run(message=response_json)

# %%
print(response.content)
# Out:
# # 2025-05-26-2025-06-01周报
#
# ## 李思齐
#
# ### 智能会议室改造
# - 完成设备安装调试完成，表单接口完成（2025-05-29）
#
# ### 财务部信息化需求
# - 完成票据托收功能（2025-05-29）
#
# ### 综合
# - 完成166Chat服务部署及上线（2025-05-28）
# - 完成166 AI服务器配置以及测试（2025-05-26）
#
# ## 陆莹辉
#
# ### 数字化企业大脑
# - 完成信息与数字化中心一部一屏需求研发穿透场景设计，初版已发布。（2025-05-30）
#
# ### 综合
# - 发布和天国际、智能、能环、重工、深圳分公司和上海分公司的名片小程序二维码。（2025-05-30）
# - 发布市场开发部、研发中心、矿业公司、水工公司、越南办事处、总图运输分院的名片小程序二维码。（2025-05-27）
